# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
car_data = pd.read_csv('D:\PENDING WORK\\new_car.csv')

# %%
car_data.head(5)
# Out:
#                       Car              Style               Range  \
# 0           Tata Nexon EV        Compact SUV  312 Km/Full Charge
# 1  Hyundai Grand i10 Nios  Compact Hatchback    20.2 - 26.2 Km/l
# 2  Maruti Suzuki Alto 800    Entry Hatchback   24.7 - 31.39 Km/l
# 3              Tata Punch        Compact SUV                 NaN
# 4               MG Hector                SUV   13.96 - 17.4 Km/l
#
#        Transmission               VehicleType        PriceRange  \
# 0         Automatic                  Electric  ₹ 13.99 - 17.4 L
# 1        AMT,Manual  Petrol,Petrol+CNG,Diesel    ₹ 5.3 - 8.51 L
# 2            Manual                       NaN   ₹ 3.39 - 5.03 L
# 3        AMT,Manual                    Petrol   ₹ 5.83 - 9.49 L
# 4  Automatic,Manual      Petrol,Diesel,Hybrid  ₹ 13.5 - 19.36 L
#
#   Rating(outof10)  Unnamed: 7  Unnamed: 8
# 0             8.5         NaN         NaN
# 1             8.5         NaN         NaN
# 2             NaN         NaN       185.0
# ...

# %%
car_data.tail(5)
# Out:
#                    Car                 Style               Range Transmission  \
# 253  Ferrari Portofino  Premium Sports Coupe             10 Km/l    Automatic
# 254            MINI SE      Luxury Hatchback  270 Km/Full Charge    Automatic
# 255                NaN                   NaN                 NaN          NaN
# 256                NaN                   NaN                 NaN          NaN
# 257                  0                   NaN                 NaN          NaN
#
#     VehicleType PriceRange Rating(outof10)  Unnamed: 7  Unnamed: 8
# 253      Petrol   ₹ 3.5 Cr              na         NaN         NaN
# 254    Electric   ₹ 47.2 L              na         NaN         NaN
# 255         NaN        NaN             NaN         NaN         NaN
# 256         NaN        NaN             NaN         NaN         NaN
# 257         NaN        NaN             185         NaN         NaN

# %%
car_data.shape
# Out:
# (258, 9)

# %%
car_data.columns
# Out:
# Index(['Car', 'Style', 'Range', 'Transmission', 'VehicleType', 'PriceRange',
#        'Rating(outof10)', 'Unnamed: 7', 'Unnamed: 8'],
#       dtype='object')

# %%
car_data.nunique()
# Out:
# Car                256
# Style               31
# Range              202
# Transmission         5
# VehicleType         15
# PriceRange         250
# Rating(outof10)     32
# Unnamed: 7           0
# Unnamed: 8           5
# dtype: int64

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Car              256 non-null    object
#  1   Style            255 non-null    object
#  2   Range            244 non-null    object
#  3   Transmission     255 non-null    object
#  4   VehicleType      254 non-null    object
#  5   PriceRange       255 non-null    object
#  6   Rating(outof10)  253 non-null    object
#  7   Unnamed: 7       0 non-null      float64
#  8   Unnamed: 8       5 non-null      float64
# dtypes: float64(2), object(7)
# memory usage: 18.3+ KB

# %%
car_data.isnull()
# Out:
#        Car  Style  Range  Transmission  VehicleType  PriceRange  \
# 0    False  False  False         False        False       False
# 1    False  False  False         False        False       False
# 2    False  False  False         False         True       False
# 3    False  False   True         False        False       False
# 4    False  False  False         False        False       False
# ..     ...    ...    ...           ...          ...         ...
# 253  False  False  False         False        False       False
# 254  False  False  False         False        False       False
# 255   True   True   True          True         True        True
# 256   True   True   True          True         True        True
# 257  False   True   True          True         True        True
#
#      Rating(outof10)  Unnamed: 7  Unnamed: 8
# 0              False        True        True
# 1              False        True        True
# 2               True        True       False
# ...

# %%
car_data.isnull().sum()
# Out:
# Car                  2
# Style                3
# Range               14
# Transmission         3
# VehicleType          4
# PriceRange           3
# Rating(outof10)      5
# Unnamed: 7         258
# Unnamed: 8         253
# dtype: int64

# %%
car_data['Style']
# Out:
# 0               Compact SUV
# 1         Compact Hatchback
# 2           Entry Hatchback
# 3               Compact SUV
# 4                       SUV
#                ...
# 253    Premium Sports Coupe
# 254        Luxury Hatchback
# 255                     NaN
# 256                     NaN
# 257                     NaN
# Name: Style, Length: 258, dtype: object

# %%
car_data['Style'].unique()
# Out:
# array(['Compact SUV', 'Compact Hatchback', 'Entry Hatchback', 'SUV',
#        'Subcompact SUV', 'Premium Hatchback', 'Compact MPV',
#        'Subcompact Sedan', 'Compact Sedan', 'Premium Fullsize SUV',
#        'Luxury SUV', 'Fullsize/Premium MPV', 'Supersports Car',
#        'Quadricycle', 'Subcompact MPV', 'Premium Midsize Sedan',
#        'Premium Luxury Sedan', 'Premium Compact Sedan',
#        'Compact SUV/Crossover', 'Midsize Sedan', 'Premium Coupe',
#        'Midsize SUV', 'Performance Sedan', 'Premium Midsize SUV',
#        'Premium Fullsize Sedan', 'Luxury Hatchback', 'Sports Car',
#        'Premium Sports Sedan', 'Premium Sports Coupe',
#        'Premium Compact SUV', 'Fullsize Sedan', nan], dtype=object)

# %%
car_data['Style'].nunique()
# Out:
# 31

# %%
car_data['Style'].value_counts()
# Out:
# SUV                       27
# Compact SUV               19
# Premium Fullsize SUV      19
# Premium Sports Coupe      15
# Luxury SUV                15
# Premium Midsize Sedan     13
# Sports Car                12
# Subcompact SUV            11
# Premium Coupe             11
# Premium Luxury Sedan      11
# Entry Hatchback           10
# Premium Midsize SUV        9
# Premium Hatchback          8
# Compact Sedan              7
# Luxury Hatchback           7
# Premium Sports Sedan       7
# Premium Fullsize Sedan     7
# Compact Hatchback          6
# Supersports Car            6
# Subcompact Sedan           5
# Fullsize/Premium MPV       5
# Subcompact MPV             4
# Compact SUV/Crossover      4
# Premium Compact SUV        3
# Compact MPV                3
# Performance Sedan          3
# Midsize Sedan              2
# Premium Compact Sedan      2
# Fullsize Sedan             2
# Midsize SUV                1
# Quadricycle                1
# Name: Style, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot('Style', data=car_data, palette='hls')
plt.xtickts(rotation = 90)
plt.show()
# Out:
# C:\Users\SANJEEV KUMAR\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [15], in <cell line: 3>()
#       1 plt.figure(figsize=(15,6))
#       2 sns.countplot('Style', data=car_data, palette='hls')
# ----> 3 plt.xtickts(rotation = 90)
#       4 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xtickts'

# %%
data = car_data.copy()

# %%
data.shape
# Out:
# (258, 9)

# %%
data['Transmission'].unique()
# Out:
# array(['Automatic', 'AMT,Manual', 'Manual', 'Automatic,Manual',
#        'AMT,Automatic,Manual', nan], dtype=object)

# %%
data['Transmission'].value_counts()
# Out:
# Automatic               169
# Automatic,Manual         45
# AMT,Manual               19
# Manual                   19
# AMT,Automatic,Manual      3
# Name: Transmission, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot('Transmission', data=car_data, palette='hls')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\SANJEEV KUMAR\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data['VehicleType'].unique()
# Out:
# array(['Electric', 'Petrol,Petrol+CNG,Diesel', nan, 'Petrol',
#        'Petrol,Diesel,Hybrid', 'Petrol,Diesel', 'Petrol,Petrol+CNG',
#        'Diesel', 'Hybrid', 'Diesel,Petrol+CNG', 'Petrol,Petrol+LPG',
#        'Diesel,Petrol', 'Diesel,Petrol,Hybrid', 'Hybrid,Petrol,Diesel',
#        'Petrol,Hybrid', 'Diesel,Hybrid'], dtype=object)

# %%
data['VehicleType'].value_counts()
# Out:
# Petrol                      127
# Petrol,Diesel                46
# Diesel                       28
# Electric                     15
# Diesel,Petrol                10
# Petrol,Petrol+CNG             9
# Hybrid                        8
# Petrol,Petrol+CNG,Diesel      2
# Petrol,Diesel,Hybrid          2
# Petrol,Hybrid                 2
# Diesel,Petrol+CNG             1
# Petrol,Petrol+LPG             1
# Diesel,Petrol,Hybrid          1
# Hybrid,Petrol,Diesel          1
# Diesel,Hybrid                 1
# Name: VehicleType, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot('VehicleType',data=data, palette='hls')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\SANJEEV KUMAR\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data.columns
# Out:
# Index(['Car', 'Style', 'Range', 'Transmission', 'VehicleType', 'PriceRange',
#        'Rating(outof10)', 'Unnamed: 7', 'Unnamed: 8'],
#       dtype='object')

# %%
data['Rating(outof10)'].value_counts()
# Out:
# na     67
# 8.2    15
# 8      14
# 7.9    14
# 7.7    14
# 7.6    13
# 8.1    13
# 7.8    12
# 7.5    10
# 8.4     9
# 8.3     9
# 7.3     8
# 8.5     6
# 7       5
# 8.7     5
# 7.1     5
# 8.8     4
# 6.5     3
# 7.4     3
# 8.6     3
# 6.4     3
# 6.8     2
# 6.1     2
# 6.9     2
# 5.5     2
# 9       2
# 7.2     2
# 6.6     2
# 5.4     1
# 5       1
# 6.3     1
# 185     1
# Name: Rating(outof10), dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot('Rating(outof10)',data=car_data,palette='hls')
plt.xtics(rotation=90)
plt.show()
# Out:
# C:\Users\SANJEEV KUMAR\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [26], in <cell line: 3>()
#       1 plt.figure(figsize=(15,6))
#       2 sns.countplot('Rating(outof10)',data=car_data,palette='hls')
# ----> 3 plt.xtics(rotation=90)
#       4 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xtics'

# %%
car_data.columns
# Out:
# Index(['Car', 'Style', 'Range', 'Transmission', 'VehicleType', 'PriceRange',
#        'Rating(outof10)', 'Unnamed: 7', 'Unnamed: 8'],
#       dtype='object')

# %%
car_data.rename(columns = {'Range':'Rangess'}, inplace = True)

# %%
car_data.head(5)
# Out:
#                       Car              Style             Rangess  \
# 0           Tata Nexon EV        Compact SUV  312 Km/Full Charge
# 1  Hyundai Grand i10 Nios  Compact Hatchback    20.2 - 26.2 Km/l
# 2  Maruti Suzuki Alto 800    Entry Hatchback   24.7 - 31.39 Km/l
# 3              Tata Punch        Compact SUV                 NaN
# 4               MG Hector                SUV   13.96 - 17.4 Km/l
#
#        Transmission               VehicleType        PriceRange  \
# 0         Automatic                  Electric  ₹ 13.99 - 17.4 L
# 1        AMT,Manual  Petrol,Petrol+CNG,Diesel    ₹ 5.3 - 8.51 L
# 2            Manual                       NaN   ₹ 3.39 - 5.03 L
# 3        AMT,Manual                    Petrol   ₹ 5.83 - 9.49 L
# 4  Automatic,Manual      Petrol,Diesel,Hybrid  ₹ 13.5 - 19.36 L
#
#   Rating(outof10)  Unnamed: 7  Unnamed: 8
# 0             8.5         NaN         NaN
# 1             8.5         NaN         NaN
# 2             NaN         NaN       185.0
# ...

# %%
car_data.drop('Unnamed: 7', axis=1)
# Out:
#                         Car                 Style             Rangess  \
# 0             Tata Nexon EV           Compact SUV  312 Km/Full Charge
# 1    Hyundai Grand i10 Nios     Compact Hatchback    20.2 - 26.2 Km/l
# 2    Maruti Suzuki Alto 800       Entry Hatchback   24.7 - 31.39 Km/l
# 3                Tata Punch           Compact SUV                 NaN
# 4                 MG Hector                   SUV   13.96 - 17.4 Km/l
# ..                      ...                   ...                 ...
# 253       Ferrari Portofino  Premium Sports Coupe             10 Km/l
# 254                 MINI SE      Luxury Hatchback  270 Km/Full Charge
# 255                     NaN                   NaN                 NaN
# 256                     NaN                   NaN                 NaN
# 257                       0                   NaN                 NaN
#
#          Transmission               VehicleType        PriceRange  \
# ...

# %%
car_data.drop('Unnamed: 8', axis=1)
# Out:
#                         Car                 Style             Rangess  \
# 0             Tata Nexon EV           Compact SUV  312 Km/Full Charge
# 1    Hyundai Grand i10 Nios     Compact Hatchback    20.2 - 26.2 Km/l
# 2    Maruti Suzuki Alto 800       Entry Hatchback   24.7 - 31.39 Km/l
# 3                Tata Punch           Compact SUV                 NaN
# 4                 MG Hector                   SUV   13.96 - 17.4 Km/l
# ..                      ...                   ...                 ...
# 253       Ferrari Portofino  Premium Sports Coupe             10 Km/l
# 254                 MINI SE      Luxury Hatchback  270 Km/Full Charge
# 255                     NaN                   NaN                 NaN
# 256                     NaN                   NaN                 NaN
# 257                       0                   NaN                 NaN
#
#          Transmission               VehicleType        PriceRange  \
# ...

# %%
car_data=car_data.drop('Unnamed: 8', axis=1)

# %%
car_data=car_data.drop('Unnamed: 7', axis=1)

# %%
car_data.head()
# Out:
#                       Car              Style             Rangess  \
# 0           Tata Nexon EV        Compact SUV  312 Km/Full Charge
# 1  Hyundai Grand i10 Nios  Compact Hatchback    20.2 - 26.2 Km/l
# 2  Maruti Suzuki Alto 800    Entry Hatchback   24.7 - 31.39 Km/l
# 3              Tata Punch        Compact SUV                 NaN
# 4               MG Hector                SUV   13.96 - 17.4 Km/l
#
#        Transmission               VehicleType        PriceRange  \
# 0         Automatic                  Electric  ₹ 13.99 - 17.4 L
# 1        AMT,Manual  Petrol,Petrol+CNG,Diesel    ₹ 5.3 - 8.51 L
# 2            Manual                       NaN   ₹ 3.39 - 5.03 L
# 3        AMT,Manual                    Petrol   ₹ 5.83 - 9.49 L
# 4  Automatic,Manual      Petrol,Diesel,Hybrid  ₹ 13.5 - 19.36 L
#
#   Rating(outof10)
# 0             8.5
# 1             8.5
# 2             NaN
# 3              na
# 4             7.5

# %%
car_data.rename(columns={'Rangess':'Range'},inplace=True)

# %%
car_data
# Out:
#                         Car                 Style               Range  \
# 0             Tata Nexon EV           Compact SUV  312 Km/Full Charge
# 1    Hyundai Grand i10 Nios     Compact Hatchback    20.2 - 26.2 Km/l
# 2    Maruti Suzuki Alto 800       Entry Hatchback   24.7 - 31.39 Km/l
# 3                Tata Punch           Compact SUV                 NaN
# 4                 MG Hector                   SUV   13.96 - 17.4 Km/l
# ..                      ...                   ...                 ...
# 253       Ferrari Portofino  Premium Sports Coupe             10 Km/l
# 254                 MINI SE      Luxury Hatchback  270 Km/Full Charge
# 255                     NaN                   NaN                 NaN
# 256                     NaN                   NaN                 NaN
# 257                       0                   NaN                 NaN
#
#          Transmission               VehicleType        PriceRange  \
# ...

# %%
car_data['Transmission'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 253    False
# 254    False
# 255     True
# 256     True
# 257     True
# Name: Transmission, Length: 258, dtype: bool

# %%
car_data['Transmission'].isnull().sum()
# Out:
# 3

# %%
car_data['Transmission'] = car_data['Transmission'].fillna('Manual')

# %%
car_data['Transmission'].isnull().sum()
# Out:
# 0

# %%
car_data['Transmission']
# Out:
# 0             Automatic
# 1            AMT,Manual
# 2                Manual
# 3            AMT,Manual
# 4      Automatic,Manual
#              ...
# 253           Automatic
# 254           Automatic
# 255              Manual
# 256              Manual
# 257              Manual
# Name: Transmission, Length: 258, dtype: object

# %%
car_data.isnull().sum()
# Out:
# Car                 2
# Style               3
# Range              14
# Transmission        0
# VehicleType         4
# PriceRange          3
# Rating(outof10)     5
# dtype: int64

# %%
car_data['Range'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 253    False
# 254    False
# 255     True
# 256     True
# 257     True
# Name: Range, Length: 258, dtype: bool

# %%
car_data['Range'].isnull().sum()
# Out:
# 14

# %%
car_data['Range'].value_counts()
# Out:
# 16 Km/l               5
# 14.4 Km/l             5
# 7 Km/l                4
# 8.5 Km/l              4
# 15 Km/l               3
#                      ..
# 20.04 - 20.65 Km/l    1
# 12.65 Km/l            1
# 16.24 - 18.97 Km/l    1
# 16.13 - 20.37 Km/l    1
# 270 Km/Full Charge    1
# Name: Range, Length: 202, dtype: int64

# %%
car_data['Range'] = car_data['Range'].fillna('15km/l')

# %%
car_data['Range'].isnull().sum()
# Out:
# 0

# %%
car_data.isnull().sum()
# Out:
# Car                2
# Style              3
# Range              0
# Transmission       0
# VehicleType        4
# PriceRange         3
# Rating(outof10)    5
# dtype: int64

# %%
car_data.head()
# Out:
#                       Car              Style               Range  \
# 0           Tata Nexon EV        Compact SUV  312 Km/Full Charge
# 1  Hyundai Grand i10 Nios  Compact Hatchback    20.2 - 26.2 Km/l
# 2  Maruti Suzuki Alto 800    Entry Hatchback   24.7 - 31.39 Km/l
# 3              Tata Punch        Compact SUV              15km/l
# 4               MG Hector                SUV   13.96 - 17.4 Km/l
#
#        Transmission               VehicleType        PriceRange  \
# 0         Automatic                  Electric  ₹ 13.99 - 17.4 L
# 1        AMT,Manual  Petrol,Petrol+CNG,Diesel    ₹ 5.3 - 8.51 L
# 2            Manual                       NaN   ₹ 3.39 - 5.03 L
# 3        AMT,Manual                    Petrol   ₹ 5.83 - 9.49 L
# 4  Automatic,Manual      Petrol,Diesel,Hybrid  ₹ 13.5 - 19.36 L
#
#   Rating(outof10)
# 0             8.5
# 1             8.5
# 2             NaN
# 3              na
# 4             7.5

# %%
car_data['Car'].count
# Out:
# <bound method Series.count of 0               Tata Nexon EV
# 1      Hyundai Grand i10 Nios
# 2      Maruti Suzuki Alto 800
# 3                  Tata Punch
# 4                   MG Hector
#                 ...
# 253         Ferrari Portofino
# 254                   MINI SE
# 255                       NaN
# 256                       NaN
# 257                         0
# Name: Car, Length: 258, dtype: object>

# %%
car_data.where(car_data['Car']=='Tata Nexon EV')
# Out:
#                Car        Style               Range Transmission VehicleType  \
# 0    Tata Nexon EV  Compact SUV  312 Km/Full Charge    Automatic    Electric
# 1              NaN          NaN                 NaN          NaN         NaN
# 2              NaN          NaN                 NaN          NaN         NaN
# 3              NaN          NaN                 NaN          NaN         NaN
# 4              NaN          NaN                 NaN          NaN         NaN
# ..             ...          ...                 ...          ...         ...
# 253            NaN          NaN                 NaN          NaN         NaN
# 254            NaN          NaN                 NaN          NaN         NaN
# 255            NaN          NaN                 NaN          NaN         NaN
# 256            NaN          NaN                 NaN          NaN         NaN
# 257            NaN          NaN                 NaN          NaN         NaN
#
#            PriceRange Rating(outof10)
# ...

# %%
car_data['Car'].value_counts()
# Out:
# Tata Nexon EV                   1
# Hyundai Grand i10 Nios          1
# Land Rover Range Rover Sport    1
# Maserati Ghibli                 1
# Maserati GranTurismo            1
#                                ..
# BMW 3 Series                    1
# Force Motors Gurkha             1
# Skoda Octavia                   1
# Volvo XC40                      1
# 0                               1
# Name: Car, Length: 256, dtype: int64

# %%
car_data
# Out:
#                         Car                 Style               Range  \
# 0             Tata Nexon EV           Compact SUV  312 Km/Full Charge
# 1    Hyundai Grand i10 Nios     Compact Hatchback    20.2 - 26.2 Km/l
# 2    Maruti Suzuki Alto 800       Entry Hatchback   24.7 - 31.39 Km/l
# 3                Tata Punch           Compact SUV              15km/l
# 4                 MG Hector                   SUV   13.96 - 17.4 Km/l
# ..                      ...                   ...                 ...
# 253       Ferrari Portofino  Premium Sports Coupe             10 Km/l
# 254                 MINI SE      Luxury Hatchback  270 Km/Full Charge
# 255                     NaN                   NaN              15km/l
# 256                     NaN                   NaN              15km/l
# 257                       0                   NaN              15km/l
#
#          Transmission               VehicleType        PriceRange  \
# ...

# %%
car_data['Transmission'].value_counts()
# Out:
# Automatic               169
# Automatic,Manual         45
# Manual                   22
# AMT,Manual               19
# AMT,Automatic,Manual      3
# Name: Transmission, dtype: int64

# %%
car_data['Transmission'].value_counts()['Manual']
# Out:
# 22

# %%
car_data['Car'].value_counts()['Tata Nexon EV']
# Out:
# 1

# %%
car_data['VehicleType'].value_counts()['Electric']
# Out:
# 15

# %%
car_data['VehicleType'].isnull().sum()
# Out:
# 4

# %%
car_data['VehicleType'].unique()
# Out:
# array(['Electric', 'Petrol,Petrol+CNG,Diesel', nan, 'Petrol',
#        'Petrol,Diesel,Hybrid', 'Petrol,Diesel', 'Petrol,Petrol+CNG',
#        'Diesel', 'Hybrid', 'Diesel,Petrol+CNG', 'Petrol,Petrol+LPG',
#        'Diesel,Petrol', 'Diesel,Petrol,Hybrid', 'Hybrid,Petrol,Diesel',
#        'Petrol,Hybrid', 'Diesel,Hybrid'], dtype=object)

# %%
car_data['VehicleType'].nunique()
# Out:
# 15

# %%
car_data.groupby(['VehicleType']).sum()
# Out:
#                                                                         Car  \
# VehicleType
# Diesel                    Mahindra ScorpioTata SafariToyota HiluxMahindr...
# Diesel,Hybrid                                                    Volvo XC60
# Diesel,Petrol             Land Rover Range RoverMercedes-Benz CLA-ClassB...
# Diesel,Petrol+CNG                                    Mahindra Bolero Pik-Up
# Diesel,Petrol,Hybrid                                           BMW 7 Series
# Electric                  Tata Nexon EVTata Tigor EVTata Nexon EV MaxMG ...
# Hybrid                    BMW i8Toyota VellfireLexus ESLexus LCVolvo XC9...
# Hybrid,Petrol,Diesel                                        Maserati Ghibli
# Petrol                    Tata PunchMaruti Suzuki BalenoMaruti Suzuki Vi...
# Petrol,Diesel             Tata NexonHyundai CretaKia SeltosMahindra Thar...
# Petrol,Diesel,Hybrid                                    MG HectorHonda City
# ...

# %%
new_car_data = car_data.copy()

# %%
new_car_data.columns
# Out:
# Index(['Car', 'Style', 'Range', 'Transmission', 'VehicleType', 'PriceRange',
#        'Rating(outof10)'],
#       dtype='object')

# %%
new_car_data['Car'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [64], in <cell line: 1>()
# ----> 1 new_car_data['Car'].mean()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:11124, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11106 @doc(
#   11107     _num_doc,
#   11108     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11122     **kwargs,
#   11123 ):
# > 11124     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:10694, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10686 def mean(
#   10687     self,
#   10688     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   10692     **kwargs,
#   10693 ) -> Series | float:
# > 10694     return self._stat_function(
# ...

# %%
new_car_data
# Out:
#                         Car                 Style               Range  \
# 0             Tata Nexon EV           Compact SUV  312 Km/Full Charge
# 1    Hyundai Grand i10 Nios     Compact Hatchback    20.2 - 26.2 Km/l
# 2    Maruti Suzuki Alto 800       Entry Hatchback   24.7 - 31.39 Km/l
# 3                Tata Punch           Compact SUV              15km/l
# 4                 MG Hector                   SUV   13.96 - 17.4 Km/l
# ..                      ...                   ...                 ...
# 253       Ferrari Portofino  Premium Sports Coupe             10 Km/l
# 254                 MINI SE      Luxury Hatchback  270 Km/Full Charge
# 255                     NaN                   NaN              15km/l
# 256                     NaN                   NaN              15km/l
# 257                       0                   NaN              15km/l
#
#          Transmission               VehicleType        PriceRange  \
# ...

# %%
new_car_data['Joining'] = new_car_data['Transmission']+ ' '+new_car_data['VehicleType']

# %%
new_car_data
# Out:
#                         Car                 Style               Range  \
# 0             Tata Nexon EV           Compact SUV  312 Km/Full Charge
# 1    Hyundai Grand i10 Nios     Compact Hatchback    20.2 - 26.2 Km/l
# 2    Maruti Suzuki Alto 800       Entry Hatchback   24.7 - 31.39 Km/l
# 3                Tata Punch           Compact SUV              15km/l
# 4                 MG Hector                   SUV   13.96 - 17.4 Km/l
# ..                      ...                   ...                 ...
# 253       Ferrari Portofino  Premium Sports Coupe             10 Km/l
# 254                 MINI SE      Luxury Hatchback  270 Km/Full Charge
# 255                     NaN                   NaN              15km/l
# 256                     NaN                   NaN              15km/l
# 257                       0                   NaN              15km/l
#
#          Transmission               VehicleType        PriceRange  \
# ...

# %%
data2=new_car_data.reset_index()

# %%
data2
# Out:
#      index                     Car                 Style               Range  \
# 0        0           Tata Nexon EV           Compact SUV  312 Km/Full Charge
# 1        1  Hyundai Grand i10 Nios     Compact Hatchback    20.2 - 26.2 Km/l
# 2        2  Maruti Suzuki Alto 800       Entry Hatchback   24.7 - 31.39 Km/l
# 3        3              Tata Punch           Compact SUV              15km/l
# 4        4               MG Hector                   SUV   13.96 - 17.4 Km/l
# ..     ...                     ...                   ...                 ...
# 253    253       Ferrari Portofino  Premium Sports Coupe             10 Km/l
# 254    254                 MINI SE      Luxury Hatchback  270 Km/Full Charge
# 255    255                     NaN                   NaN              15km/l
# 256    256                     NaN                   NaN              15km/l
# 257    257                       0                   NaN              15km/l
#
# ...

# %%
data2=data2.drop('index',axis=1)

# %%
data2
# Out:
#                         Car                 Style               Range  \
# 0             Tata Nexon EV           Compact SUV  312 Km/Full Charge
# 1    Hyundai Grand i10 Nios     Compact Hatchback    20.2 - 26.2 Km/l
# 2    Maruti Suzuki Alto 800       Entry Hatchback   24.7 - 31.39 Km/l
# 3                Tata Punch           Compact SUV              15km/l
# 4                 MG Hector                   SUV   13.96 - 17.4 Km/l
# ..                      ...                   ...                 ...
# 253       Ferrari Portofino  Premium Sports Coupe             10 Km/l
# 254                 MINI SE      Luxury Hatchback  270 Km/Full Charge
# 255                     NaN                   NaN              15km/l
# 256                     NaN                   NaN              15km/l
# 257                       0                   NaN              15km/l
#
#          Transmission               VehicleType        PriceRange  \
# ...

# %%
data2=data2['Style'].fillna(value='Compact SUV',inplace=True)

# %%
data2

# %%
data2

# %%
new_car_data.size
# Out:
# 2064

# %%
new_car_data.shape
# Out:
# (258, 8)

# %%
new_car_data.head()
# Out:
#                       Car              Style               Range  \
# 0           Tata Nexon EV        Compact SUV  312 Km/Full Charge
# 1  Hyundai Grand i10 Nios  Compact Hatchback    20.2 - 26.2 Km/l
# 2  Maruti Suzuki Alto 800    Entry Hatchback   24.7 - 31.39 Km/l
# 3              Tata Punch        Compact SUV              15km/l
# 4               MG Hector                SUV   13.96 - 17.4 Km/l
#
#        Transmission               VehicleType        PriceRange  \
# 0         Automatic                  Electric  ₹ 13.99 - 17.4 L
# 1        AMT,Manual  Petrol,Petrol+CNG,Diesel    ₹ 5.3 - 8.51 L
# 2            Manual                       NaN   ₹ 3.39 - 5.03 L
# 3        AMT,Manual                    Petrol   ₹ 5.83 - 9.49 L
# 4  Automatic,Manual      Petrol,Diesel,Hybrid  ₹ 13.5 - 19.36 L
#
#   Rating(outof10)                                Joining
# 0             8.5                     Automatic Electric
# 1             8.5    AMT,Manual Petrol,Petrol+CNG,Diesel
# ...

# %%
new_car_data.dtypes
# Out:
# Car                object
# Style              object
# Range              object
# Transmission       object
# VehicleType        object
# PriceRange         object
# Rating(outof10)    object
# Joining            object
# dtype: object

# %%
df1 = new_car_data.copy()
df1["Range"] = df1["Range"].astype("int64")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [85], in <cell line: 2>()
#       1 df1 = new_car_data.copy()
# ----> 2 df1["Range"] = df1["Range"].astype("int64")
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df1
# Out:
#                         Car                 Style               Range  \
# 0             Tata Nexon EV           Compact SUV  312 Km/Full Charge
# 1    Hyundai Grand i10 Nios     Compact Hatchback    20.2 - 26.2 Km/l
# 2    Maruti Suzuki Alto 800       Entry Hatchback   24.7 - 31.39 Km/l
# 3                Tata Punch           Compact SUV              15km/l
# 4                 MG Hector                   SUV   13.96 - 17.4 Km/l
# ..                      ...                   ...                 ...
# 253       Ferrari Portofino  Premium Sports Coupe             10 Km/l
# 254                 MINI SE      Luxury Hatchback  270 Km/Full Charge
# 255                     NaN                   NaN              15km/l
# 256                     NaN                   NaN              15km/l
# 257                       0                   NaN              15km/l
#
#          Transmission               VehicleType        PriceRange  \
# ...

# %%
df1.sort_values("Car")
# Out:
#                       Car                  Style       Range Transmission  \
# 257                     0                    NaN      15km/l       Manual
# 143     Aston Martin DB11   Premium Sports Coupe     12 Km/l    Automatic
# 242      Aston Martin DBX   Premium Sports Sedan     12 Km/l    Automatic
# 156  Aston Martin Vantage   Premium Sports Coupe      7 Km/l    Automatic
# 106               Audi A4  Premium Midsize Sedan  17.84 Km/l    Automatic
# ..                    ...                    ...         ...          ...
# 93             Volvo XC40                    SUV     18 Km/l    Automatic
# 202            Volvo XC60    Premium Midsize SUV   13.8 Km/l    Automatic
# 134            Volvo XC90   Premium Fullsize SUV   16.6 Km/l    Automatic
# 255                   NaN                    NaN      15km/l       Manual
# 256                   NaN                    NaN      15km/l       Manual
#
#        VehicleType         PriceRange Rating(outof10)                  Joining
# ...

# %%
df1
# Out:
#                         Car                 Style               Range  \
# 0             Tata Nexon EV           Compact SUV  312 Km/Full Charge
# 1    Hyundai Grand i10 Nios     Compact Hatchback    20.2 - 26.2 Km/l
# 2    Maruti Suzuki Alto 800       Entry Hatchback   24.7 - 31.39 Km/l
# 3                Tata Punch           Compact SUV              15km/l
# 4                 MG Hector                   SUV   13.96 - 17.4 Km/l
# ..                      ...                   ...                 ...
# 253       Ferrari Portofino  Premium Sports Coupe             10 Km/l
# 254                 MINI SE      Luxury Hatchback  270 Km/Full Charge
# 255                     NaN                   NaN              15km/l
# 256                     NaN                   NaN              15km/l
# 257                       0                   NaN              15km/l
#
#          Transmission               VehicleType        PriceRange  \
# ...

# %%
plt.figure(figsize=(15,6))
sns.jointplot(x='Car', y='Range', data=df1, color="green")
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x='Style', y='Rating(outof10)',data=new_car_data,palette='hls')
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [94], in <cell line: 2>()
#       1 plt.figure(figsize=(15,6))
# ----> 2 sns.boxplot(x='Style', y='Rating(outof10)',data=new_car_data,palette='hls')
#       3 plt.xticks(rotation=90)
#       4 plt.show()
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...
