# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('D:\Dataset\zomato.csv',encoding_errors= 'replace')

# %%
df
# Out:
#       Restaurant ID         Restaurant Name  Country Code              City  \
# 0           6317637        Le Petit Souffle           162       Makati City
# 1           6304287        Izakaya Kikufuji           162       Makati City
# 2           6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                    Ooma           162  Mandaluyong City
# 4           6314302             Sambo Kojin           162  Mandaluyong City
# ...             ...                     ...           ...               ...
# 9367        7602219                 Bentoya           215         Edinburgh
# 9368        7602224               Civerinos           215         Edinburgh
# 9369        7600471      The Elephant House           215         Edinburgh
# 9370        7600118         The Hanging Bat           215         Edinburgh
# 9371        7600097             Love Crumbs           215         Edinburgh
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2     Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3     Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4     Third Floor, Mega Atrium, SM Megamall, Ortigas...
# ...                                                 ...
# 9367       15 Bread Street, Old Town, Edinburgh EH3 9AL
# 9368  5 Hunter Square, Royal Mile, Old Town, Edinbur...
# 9369   21 George IV Bridge, Old Town, Edinburgh EH1 1EN
# 9370      133 Lothian Road, Old Town, Edinburgh EH3 9AD
# 9371         155 West Port, Old Town, Edinburgh EH3 9DP
#
#                                         Locality  \
# 0      Century City Mall, Poblacion, Makati City
# 1     Little Tokyo, Legaspi Village, Makati City
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City
# 3         SM Megamall, Ortigas, Mandaluyong City
# 4         SM Megamall, Ortigas, Mandaluyong City
# ...                                          ...
# 9367                                    Old Town
# 9368                                    Old Town
# 9369                                    Old Town
# 9370                                    Old Town
# 9371                                    Old Town
#
#                                        Locality Verbose   Longitude  \
# 0     Century City Mall, Poblacion, Makati City, Mak...  121.027535
# 1     Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831
# 3     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475
# 4     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508
# ...                                                 ...         ...
# 9367                                Old Town, Edinburgh   -3.204735
# 9368                                Old Town, Edinburgh   -3.187962
# 9369                                Old Town, Edinburgh   -3.191781
# 9370                                Old Town, Edinburgh   -3.205522
# 9371                                Old Town, Edinburgh   -3.201683
#
#        Latitude                          Cuisines  ...          Currency  \
# 0     14.565443        French, Japanese, Desserts  ...  Botswana Pula(P)
# 1     14.553708                          Japanese  ...  Botswana Pula(P)
# 2     14.581404  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)
# 3     14.585318                   Japanese, Sushi  ...  Botswana Pula(P)
# 4     14.584450                  Japanese, Korean  ...  Botswana Pula(P)
# ...         ...                               ...  ...               ...
# 9367  55.945895        Sushi, Japanese, Cantonese  ...        Pounds(��)
# 9368  55.949637                    Pizza, Italian  ...        Pounds(��)
# 9369  55.947556                              Cafe  ...        Pounds(��)
# 9370  55.945622                          American  ...        Pounds(��)
# 9371  55.945950                      Bakery, Cafe  ...        Pounds(��)
#
#      Has Table booking Has Online delivery Is delivering now  \
# 0                  Yes                  No                No
# 1                  Yes                  No                No
# 2                  Yes                  No                No
# 3                   No                  No                No
# 4                  Yes                  No                No
# ...                ...                 ...               ...
# 9367                No                  No                No
# 9368                No                  No                No
# 9369                No                  No                No
# 9370                No                  No                No
# 9371                No                  No                No
#
#      Switch to order menu Price range  Aggregate rating  Rating color  \
# 0                      No           3               4.8    Dark Green
# 1                      No           3               4.5    Dark Green
# 2                      No           4               4.4         Green
# 3                      No           4               4.9    Dark Green
# 4                      No           4               4.8    Dark Green
# ...                   ...         ...               ...           ...
# 9367                   No           2               3.8        Yellow
# 9368                   No           3               3.7        Yellow
# 9369                   No           3               3.9        Yellow
# 9370                   No           3               3.5        Yellow
# 9371                   No           2               4.1         Green
#
#      Rating text Votes
# 0      Excellent   314
# 1      Excellent   591
# 2      Very Good   270
# 3      Excellent   365
# 4      Excellent   229
# ...          ...   ...
# 9367        Good    32
# 9368        Good    27
# 9369        Good    81
# 9370        Good    31
# 9371   Very Good    57
#
# [9372 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of       Restaurant ID         Restaurant Name  Country Code              City  \
# 0           6317637        Le Petit Souffle           162       Makati City
# 1           6304287        Izakaya Kikufuji           162       Makati City
# 2           6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                    Ooma           162  Mandaluyong City
# 4           6314302             Sambo Kojin           162  Mandaluyong City
# ...             ...                     ...           ...               ...
# 9367        7602219                 Bentoya           215         Edinburgh
# 9368        7602224               Civerinos           215         Edinburgh
# 9369        7600471      The Elephant House           215         Edinburgh
# 9370        7600118         The Hanging Bat           215         Edinburgh
# 9371        7600097             Love Crumbs           215         Edinburgh
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2     Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3     Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4     Third Floor, Mega Atrium, SM Megamall, Ortigas...
# ...                                                 ...
# 9367       15 Bread Street, Old Town, Edinburgh EH3 9AL
# 9368  5 Hunter Square, Royal Mile, Old Town, Edinbur...
# 9369   21 George IV Bridge, Old Town, Edinburgh EH1 1EN
# 9370      133 Lothian Road, Old Town, Edinburgh EH3 9AD
# 9371         155 West Port, Old Town, Edinburgh EH3 9DP
#
#                                         Locality  \
# 0      Century City Mall, Poblacion, Makati City
# 1     Little Tokyo, Legaspi Village, Makati City
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City
# 3         SM Megamall, Ortigas, Mandaluyong City
# 4         SM Megamall, Ortigas, Mandaluyong City
# ...                                          ...
# 9367                                    Old Town
# 9368                                    Old Town
# 9369                                    Old Town
# 9370                                    Old Town
# 9371                                    Old Town
#
#                                        Locality Verbose   Longitude  \
# 0     Century City Mall, Poblacion, Makati City, Mak...  121.027535
# 1     Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831
# 3     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475
# 4     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508
# ...                                                 ...         ...
# 9367                                Old Town, Edinburgh   -3.204735
# 9368                                Old Town, Edinburgh   -3.187962
# 9369                                Old Town, Edinburgh   -3.191781
# 9370                                Old Town, Edinburgh   -3.205522
# 9371                                Old Town, Edinburgh   -3.201683
#
#        Latitude                          Cuisines  ...          Currency  \
# 0     14.565443        French, Japanese, Desserts  ...  Botswana Pula(P)
# 1     14.553708                          Japanese  ...  Botswana Pula(P)
# 2     14.581404  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)
# 3     14.585318                   Japanese, Sushi  ...  Botswana Pula(P)
# 4     14.584450                  Japanese, Korean  ...  Botswana Pula(P)
# ...         ...                               ...  ...               ...
# 9367  55.945895        Sushi, Japanese, Cantonese  ...        Pounds(��)
# 9368  55.949637                    Pizza, Italian  ...        Pounds(��)
# 9369  55.947556                              Cafe  ...        Pounds(��)
# 9370  55.945622                          American  ...        Pounds(��)
# 9371  55.945950                      Bakery, Cafe  ...        Pounds(��)
#
#      Has Table booking Has Online delivery Is delivering now  \
# 0                  Yes                  No                No
# 1                  Yes                  No                No
# 2                  Yes                  No                No
# 3                   No                  No                No
# 4                  Yes                  No                No
# ...                ...                 ...               ...
# 9367                No                  No                No
# 9368                No                  No                No
# 9369                No                  No                No
# 9370                No                  No                No
# 9371                No                  No                No
#
#      Switch to order menu Price range  Aggregate rating  Rating color  \
# 0                      No           3               4.8    Dark Green
# 1                      No           3               4.5    Dark Green
# 2                      No           4               4.4         Green
# 3                      No           4               4.9    Dark Green
# 4                      No           4               4.8    Dark Green
# ...                   ...         ...               ...           ...
# 9367                   No           2               3.8        Yellow
# 9368                   No           3               3.7        Yellow
# 9369                   No           3               3.9        Yellow
# 9370                   No           3               3.5        Yellow
# 9371                   No           2               4.1         Green
#
#      Rating text Votes
# 0      Excellent   314
# 1      Excellent   591
# 2      Very Good   270
# 3      Excellent   365
# 4      Excellent   229
# ...          ...   ...
# 9367        Good    32
# 9368        Good    27
# 9369        Good    81
# 9370        Good    31
# 9371   Very Good    57
#
# [9372 rows x 21 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9372 entries, 0 to 9371
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9372 non-null   int64
#  1   Restaurant Name       9372 non-null   object
#  2   Country Code          9372 non-null   int64
#  3   City                  9372 non-null   object
#  4   Address               9372 non-null   object
#  5   Locality              9372 non-null   object
#  6   Locality Verbose      9372 non-null   object
#  7   Longitude             9372 non-null   float64
#  8   Latitude              9372 non-null   float64
#  9   Cuisines              9363 non-null   object
#  10  Average Cost for two  9372 non-null   int64
#  11  Currency              9372 non-null   object
#  12  Has Table booking     9372 non-null   object
#  13  Has Online delivery   9372 non-null   object
#  14  Is delivering now     9372 non-null   object
#  15  Switch to order menu  9372 non-null   object
#  16  Price range           9372 non-null   int64
#  17  Aggregate rating      9372 non-null   float64
#  18  Rating color          9372 non-null   object
#  19  Rating text           9372 non-null   object
#  20  Votes                 9372 non-null   int64
# dtypes: float64(3), int64(5), object(13)
# memory usage: 1.5+ MB

# %%
df.isnull()
# Out:
#       Restaurant ID  Restaurant Name  Country Code   City  Address  Locality  \
# 0             False            False         False  False    False     False
# 1             False            False         False  False    False     False
# 2             False            False         False  False    False     False
# 3             False            False         False  False    False     False
# 4             False            False         False  False    False     False
# ...             ...              ...           ...    ...      ...       ...
# 9367          False            False         False  False    False     False
# 9368          False            False         False  False    False     False
# 9369          False            False         False  False    False     False
# 9370          False            False         False  False    False     False
# 9371          False            False         False  False    False     False
#
#       Locality Verbose  Longitude  Latitude  Cuisines  ...  Currency  \
# 0                False      False     False     False  ...     False
# 1                False      False     False     False  ...     False
# 2                False      False     False     False  ...     False
# 3                False      False     False     False  ...     False
# 4                False      False     False     False  ...     False
# ...                ...        ...       ...       ...  ...       ...
# 9367             False      False     False     False  ...     False
# 9368             False      False     False     False  ...     False
# 9369             False      False     False     False  ...     False
# 9370             False      False     False     False  ...     False
# 9371             False      False     False     False  ...     False
#
#       Has Table booking  Has Online delivery  Is delivering now  \
# 0                 False                False              False
# 1                 False                False              False
# 2                 False                False              False
# 3                 False                False              False
# 4                 False                False              False
# ...                 ...                  ...                ...
# 9367              False                False              False
# 9368              False                False              False
# 9369              False                False              False
# 9370              False                False              False
# 9371              False                False              False
#
#       Switch to order menu  Price range  Aggregate rating  Rating color  \
# 0                    False        False             False         False
# 1                    False        False             False         False
# 2                    False        False             False         False
# 3                    False        False             False         False
# 4                    False        False             False         False
# ...                    ...          ...               ...           ...
# 9367                 False        False             False         False
# 9368                 False        False             False         False
# 9369                 False        False             False         False
# 9370                 False        False             False         False
# 9371                 False        False             False         False
#
#       Rating text  Votes
# 0           False  False
# 1           False  False
# 2           False  False
# 3           False  False
# 4           False  False
# ...           ...    ...
# 9367        False  False
# 9368        False  False
# 9369        False  False
# 9370        False  False
# 9371        False  False
#
# [9372 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
[features for features in df.columns if df[features].isnull().sum()>0]
# Out:
# ['Cuisines']

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df_country=pd.read_excel('D:\Dataset\Country-Code.xlsx')

# %%
df_country
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
final_df=pd.merge(df,df_country,on='Country Code',how='left')

# %%
final_df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...  Has Table booking  \
# 0        French, Japanese, Desserts  ...                Yes
# 1                          Japanese  ...                Yes
# 2  Seafood, Asian, Filipino, Indian  ...                Yes
# 3                   Japanese, Sushi  ...                 No
# 4                  Japanese, Korean  ...                Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#   Aggregate rating  Rating color  Rating text Votes      Country
# 0              4.8    Dark Green    Excellent   314  Phillipines
# 1              4.5    Dark Green    Excellent   591  Phillipines
# 2              4.4         Green    Very Good   270  Phillipines
# 3              4.9    Dark Green    Excellent   365  Phillipines
# 4              4.8    Dark Green    Excellent   229  Phillipines
#
# [5 rows x 22 columns]

# %%
country_name=final_df.Country.value_counts().index

# %%
country_name
# Out:
# Index(['India', 'United States', 'Brazil', 'UAE', 'New Zealand',
#        'United Kingdom', 'Australia', 'Phillipines', 'Indonesia', 'Singapore',
#        'Canada'],
#       dtype='object')

# %%
country_val=final_df.Country.value_counts().values
country_val
# Out:
# array([8652,  434,   60,   60,   40,   35,   24,   22,   21,   20,    4],
#       dtype=int64)

# %%
plt.pie(country_val[:3],labels=country_name[:3],autopct="%1.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x2748ec9f670>,
#   <matplotlib.patches.Wedge at 0x2748ec9fdc0>,
#   <matplotlib.patches.Wedge at 0x2748eca9520>],
#  [Text(-1.0842016695843655, 0.18575989790714992, 'India'),
#   Text(1.080143265466555, -0.20806375481387324, 'United States'),
#   Text(1.0997663961943693, -0.02266878474135342, 'Brazil')],
#  [Text(-0.5913827288641993, 0.10132358067662721, '94.60%'),
#   Text(0.5891690538908481, -0.11348932080756721, '4.75%'),
#   Text(0.5998725797423832, -0.012364791677101866, '0.66%')])

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
rating = final_df.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns = {0:'Rating count'})

# %%
rating.head(5)
# Out:
#    Aggregate rating Rating color Rating text  Rating count
# 0               0.0        White   Not rated          2148
# 1               1.8          Red        Poor             1
# 2               1.9          Red        Poor             2
# 3               2.0          Red        Poor             7
# 4               2.1          Red        Poor            15

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=(12,6)
sns.barplot(x="Aggregate rating",y="Rating count",data=rating)
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating count'>

# %%
sns.barplot(x="Aggregate rating",y="Rating count",hue='Rating color',data=rating,palette=['blue','red','orange','yellow','green','green'])
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating count'>

# %%
sns.countplot(x="Rating color",data=rating,palette=['blue','red','orange','yellow','green','green'])
# Out:
# <AxesSubplot:xlabel='Rating color', ylabel='count'>

# %%
final_df.groupby(['Aggregate rating','Country']).size().reset_index().head(5)
# Out:
#    Aggregate rating         Country     0
# 0               0.0          Brazil     5
# 1               0.0           India  2139
# 2               0.0  United Kingdom     1
# 3               0.0   United States     3
# 4               1.8           India     1

# %%
final_df[['Country','Currency']].groupby(['Country','Currency']).size().reset_index()
# Out:
#            Country                Currency     0
# 0        Australia               Dollar($)    24
# 1           Brazil      Brazilian Real(R$)    60
# 2           Canada               Dollar($)     4
# 3            India      Indian Rupees(Rs.)  8652
# 4        Indonesia  Indonesian Rupiah(IDR)    21
# 5      New Zealand           NewZealand($)    40
# 6      Phillipines        Botswana Pula(P)    22
# 7        Singapore               Dollar($)    20
# 8              UAE      Emirati Diram(AED)    60
# 9   United Kingdom              Pounds(��)    35
# 10   United States               Dollar($)   434

# %%
final_df[final_df['Has Online delivery']=="Yes"].Country.value_counts()
# Out:
# India    2423
# UAE        28
# Name: Country, dtype: int64

# %%
final_df[['Has Online delivery','Country']].groupby(['Has Online delivery','Country']).size().reset_index()
# Out:
#    Has Online delivery         Country     0
# 0                   No       Australia    24
# 1                   No          Brazil    60
# 2                   No          Canada     4
# 3                   No           India  6229
# 4                   No       Indonesia    21
# 5                   No     New Zealand    40
# 6                   No     Phillipines    22
# 7                   No       Singapore    20
# 8                   No             UAE    32
# 9                   No  United Kingdom    35
# 10                  No   United States   434
# 11                 Yes           India  2423
# 12                 Yes             UAE    28

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df.City.value_counts().index
# Out:
# Index(['New Delhi', 'Gurgaon', 'Noida', 'Faridabad', 'Ghaziabad', 'Lucknow',
#        'Amritsar', 'Guwahati', 'Bhubaneshwar', 'Ahmedabad',
#        ...
#        'Miller', 'Middleton Beach', 'Mc Millan', 'Mayfield', 'Macedon', 'Lorn',
#        'Lincoln', 'Lakeview', 'Lakes Entrance', 'Huskisson'],
#       dtype='object', length=129)

# %%
city_values = final_df.City.value_counts().values
city_labels = final_df.City.value_counts().index

# %%
plt.pie(city_values[:5],labels=city_labels[:5],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2748f969790>,
#   <matplotlib.patches.Wedge at 0x2748f969eb0>,
#   <matplotlib.patches.Wedge at 0x2748f977610>,
#   <matplotlib.patches.Wedge at 0x2748f977d60>,
#   <matplotlib.patches.Wedge at 0x2748f9844f0>],
#  [Text(-0.6145352824185932, 0.9123301960708633, 'New Delhi'),
#   Text(0.0623675251198054, -1.0982305276263407, 'Gurgaon'),
#   Text(0.8789045225625368, -0.6614581167535246, 'Noida'),
#   Text(1.0922218418223437, -0.13058119407559224, 'Faridabad'),
#   Text(1.099946280005612, -0.010871113182029924, 'Ghaziabad')],
#  [Text(-0.3352010631374145, 0.497634652402289, '68.87%'),
#   Text(0.0340186500653484, -0.5990348332507311, '14.07%'),
#   Text(0.47940246685229276, -0.36079533641101336, '13.59%'),
#   Text(0.5957573682667329, -0.07122610585941394, '3.16%'),
#   Text(0.5999706981848791, -0.005929698099289049, '0.31%')])

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df.Cuisines.value_counts().index
# Out:
# Index(['North Indian', 'North Indian, Chinese', 'Fast Food', 'Chinese',
#        'North Indian, Mughlai', 'Cafe', 'Bakery',
#        'North Indian, Mughlai, Chinese', 'Bakery, Desserts', 'Street Food',
#        ...
#        'Asian, Seafood', 'Continental, Italian, North Indian, American',
#        'Chinese, Continental, North Indian, Mexican',
#        'North Indian, Italian, Chinese, American',
#        'Portuguese, African, Lebanese',
#        'Continental, Burger, Pizza, North Indian, European, Finger Food',
#        'Continental, North Indian, Chinese, European, Asian',
#        'Mexican, Italian, North Indian, Chinese',
#        'Mithai, North Indian, South Indian, Fast Food, Street Food, Chinese',
#        'Sushi, Japanese, Cantonese'],
#       dtype='object', length=1738)

# %%
Cuisines_values = final_df.Cuisines.value_counts().values
Cuisines_labels = final_df.Cuisines.value_counts().index

# %%
plt.pie(Cuisines_values[:10],labels=Cuisines_labels[:10],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2748f9c94c0>,
#   <matplotlib.patches.Wedge at 0x2748f9c9be0>,
#   <matplotlib.patches.Wedge at 0x2748f9d5370>,
#   <matplotlib.patches.Wedge at 0x2748f9d5a90>,
#   <matplotlib.patches.Wedge at 0x2748f9e31f0>,
#   <matplotlib.patches.Wedge at 0x2748f9e3910>,
#   <matplotlib.patches.Wedge at 0x2748f9ee070>,
#   <matplotlib.patches.Wedge at 0x2748f9ee790>,
#   <matplotlib.patches.Wedge at 0x2748f9eeeb0>,
#   <matplotlib.patches.Wedge at 0x2748f9fc610>],
#  [Text(0.7362387007499412, 0.8172836567055765, 'North Indian'),
#   Text(-0.5856816684354323, 0.9311159880802652, 'North Indian, Chinese'),
#   Text(-1.0694516173820607, 0.25743589120185734, 'Fast Food'),
#   Text(-1.015465243438943, -0.42288336378662145, 'Chinese'),
#   Text(-0.5865145879901585, -0.9305915527634747, 'North Indian, Mughlai'),
#   Text(-0.003444913653238246, -1.0999946057003742, 'Cafe'),
#   Text(0.4807529761497664, -0.989381916108811, 'Bakery'),
#   Text(0.8069943475745431, -0.7475025906194155, 'North Indian, Mughlai, Chinese'),
#   Text(1.0049533642759607, -0.4472904376693385, 'Bakery, Desserts'),
#   Text(1.0902381959668621, -0.14622132558188033, 'Street Food')],
#  [Text(0.4015847458636043, 0.4457910854757689, '26.66%'),
#   Text(-0.3194627282375085, 0.507881448043781, '14.55%'),
#   Text(-0.5833372458447603, 0.14041957701919489, '10.05%'),
#   Text(-0.553890132784878, -0.23066365297452077, '10.03%'),
#   Text(-0.3199170479946319, -0.5075953924164407, '9.51%'),
#   Text(-0.0018790438108572248, -0.5999970576547495, '8.29%'),
#   Text(0.26222889608169075, -0.5396628633320787, '6.21%'),
#   Text(0.44017873504065985, -0.40772868579240845, '5.61%'),
#   Text(0.5481563805141603, -0.24397660236509372, '4.84%'),
#   Text(0.5946753796182883, -0.07975708668102563, '4.24%')])
